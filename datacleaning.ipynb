# %%
import pandas as pd
import numpy as np

# %%
crash_data = pd.read_csv('crash_reports.csv', skiprows=11, header=0)

# %%
crash_data.head()
# Out:
#    Crash ID                 City Commercial Motor Vehicle Flag   County  \
# 0  18674968  OUTSIDE CITY LIMITS                           Yes   HARRIS
# 1  18676126                PHARR                           Yes  HIDALGO
# 2  18676126                PHARR                           Yes  HIDALGO
# 3  18676126                PHARR                           Yes  HIDALGO
# 4  18679166        GRAND PRAIRIE                           Yes  TARRANT
#
#    Crash Date                Crash Severity  Crash Time Day of Week  \
# 0  2022-01-01  A - SUSPECTED SERIOUS INJURY        1449    SATURDAY
# 1  2022-01-01  A - SUSPECTED SERIOUS INJURY        1528    SATURDAY
# 2  2022-01-01  A - SUSPECTED SERIOUS INJURY        1528    SATURDAY
# 3  2022-01-01  A - SUSPECTED SERIOUS INJURY        1528    SATURDAY
# 4  2022-01-01  A - SUSPECTED SERIOUS INJURY        2132    SATURDAY
#
#       Latitude     Longitude  ... Weather Condition  \
# 0  30.08917859  -95.45875665  ...        2 - CLOUDY
# 1  26.20601218  -98.17643094  ...         1 - CLEAR
# 2  26.20601218  -98.17643094  ...         1 - CLEAR
# 3  26.20601218  -98.17643094  ...         1 - CLEAR
# 4  32.77855464  -97.06134716  ...         1 - CLEAR
#
#                             CMV Sequence of Events 1 CMV Sequence of Events 2  \
# 0              18 - COLLISION INVOLVING FIXED OBJECT                  No Data
# 1                                            No Data                  No Data
# 2                                            No Data                  No Data
# 3  13 - COLLISION INVOLVING MOTOR VEHICLE IN TRAN...                  No Data
# 4                                            No Data                  No Data
#
#   CMV Sequence of Events 3 CMV Sequence of Events 4  \
# 0                  No Data                  No Data
# 1                  No Data                  No Data
# 2                  No Data                  No Data
# 3                  No Data                  No Data
# 4                  No Data                  No Data
#
#              Contributing Factor 1 Person Age Person Gender  \
# 0  47 - ILL (EXPLAIN IN NARRATIVE)         34      1 - MALE
# 1     22 - FAILED TO CONTROL SPEED         32      1 - MALE
# 2                          No Data         57      1 - MALE
# 3     22 - FAILED TO CONTROL SPEED         42      1 - MALE
# 4     22 - FAILED TO CONTROL SPEED         20    2 - FEMALE
#
#          Person Injury Severity                            Person Type
# 0  A - SUSPECTED SERIOUS INJURY                             1 - DRIVER
# 1           C - POSSIBLE INJURY                             1 - DRIVER
# 2  A - SUSPECTED SERIOUS INJURY  5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 3    B - SUSPECTED MINOR INJURY                             1 - DRIVER
# 4  A - SUSPECTED SERIOUS INJURY                             1 - DRIVER
#
# [5 rows x 23 columns]

# %%
crash_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6095 entries, 0 to 6094
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       6095 non-null   int64
#  1   City                           6095 non-null   object
#  2   Commercial Motor Vehicle Flag  6095 non-null   object
#  3   County                         6095 non-null   object
#  4   Crash Date                     6095 non-null   object
#  5   Crash Severity                 6095 non-null   object
#  6   Crash Time                     6095 non-null   int64
#  7   Day of Week                    6095 non-null   object
#  8   Latitude                       6095 non-null   object
#  9   Longitude                      6095 non-null   object
#  10  School Bus Flag                6095 non-null   object
#  11  Speed Limit                    6095 non-null   int64
#  12  Surface Condition              6095 non-null   object
#  13  Weather Condition              6095 non-null   object
#  14  CMV Sequence of Events 1       6095 non-null   object
#  15  CMV Sequence of Events 2       6095 non-null   object
#  16  CMV Sequence of Events 3       6095 non-null   object
#  17  CMV Sequence of Events 4       6095 non-null   object
#  18  Contributing Factor 1          6095 non-null   object
#  19  Person Age                     6095 non-null   object
#  20  Person Gender                  6095 non-null   object
#  21  Person Injury Severity         6095 non-null   object
#  22  Person Type                    6095 non-null   object
# dtypes: int64(3), object(20)
# memory usage: 1.1+ MB

# %%
crash_data['Crash Date'] = pd.to_datetime(crash_data['Crash Date'])
crash_data['Crash Time'] = pd.to_datetime(crash_data['Crash Time'])

# %%
crash_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6095 entries, 0 to 6094
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       6095 non-null   int64
#  1   City                           6095 non-null   object
#  2   Commercial Motor Vehicle Flag  6095 non-null   object
#  3   County                         6095 non-null   object
#  4   Crash Date                     6095 non-null   datetime64[ns]
#  5   Crash Severity                 6095 non-null   object
#  6   Crash Time                     6095 non-null   datetime64[ns]
#  7   Day of Week                    6095 non-null   object
#  8   Latitude                       6095 non-null   object
#  9   Longitude                      6095 non-null   object
#  10  School Bus Flag                6095 non-null   object
#  11  Speed Limit                    6095 non-null   int64
#  12  Surface Condition              6095 non-null   object
#  13  Weather Condition              6095 non-null   object
#  14  CMV Sequence of Events 1       6095 non-null   object
#  15  CMV Sequence of Events 2       6095 non-null   object
#  16  CMV Sequence of Events 3       6095 non-null   object
#  17  CMV Sequence of Events 4       6095 non-null   object
#  18  Contributing Factor 1          6095 non-null   object
#  19  Person Age                     6095 non-null   object
#  20  Person Gender                  6095 non-null   object
#  21  Person Injury Severity         6095 non-null   object
#  22  Person Type                    6095 non-null   object
# dtypes: datetime64[ns](2), int64(2), object(19)
# memory usage: 1.1+ MB

# %%
(crash_data.isna().sum() + (crash_data == 'No Data').sum())
# Out:
# Crash ID                            0
# City                                0
# Commercial Motor Vehicle Flag       0
# County                              0
# Crash Date                          0
# Crash Severity                      0
# Crash Time                          0
# Day of Week                         0
# Latitude                          210
# Longitude                         210
# School Bus Flag                     0
# Speed Limit                         0
# Surface Condition                   0
# Weather Condition                   0
# CMV Sequence of Events 1         3031
# CMV Sequence of Events 2         5446
# CMV Sequence of Events 3         5833
# CMV Sequence of Events 4         6005
# Contributing Factor 1            2995
# Person Age                         73
# Person Gender                       0
# Person Injury Severity              0
# Person Type                         0
# dtype: int64

# %%
crash_data
# Out:
#       Crash ID                 City Commercial Motor Vehicle Flag   County  \
# 0     18674968  OUTSIDE CITY LIMITS                           Yes   HARRIS
# 1     18676126                PHARR                           Yes  HIDALGO
# 2     18676126                PHARR                           Yes  HIDALGO
# 3     18676126                PHARR                           Yes  HIDALGO
# 4     18679166        GRAND PRAIRIE                           Yes  TARRANT
# ...        ...                  ...                           ...      ...
# 6090  19325090  OUTSIDE CITY LIMITS                           Yes   HARRIS
# 6091  19366862               IRVING                           Yes   DALLAS
# 6092  19366862               IRVING                           Yes   DALLAS
# 6093  19415282              HOUSTON                           Yes   HARRIS
# 6094  19415282              HOUSTON                           Yes   HARRIS
#
#      Crash Date                Crash Severity                    Crash Time  \
# 0    2022-01-01  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001449
# 1    2022-01-01  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001528
# 2    2022-01-01  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001528
# 3    2022-01-01  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001528
# 4    2022-01-01  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000002132
# ...         ...                           ...                           ...
# 6090 2022-12-31  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001222
# 6091 2022-12-31              K - FATAL INJURY 1970-01-01 00:00:00.000000710
# 6092 2022-12-31              K - FATAL INJURY 1970-01-01 00:00:00.000000710
# 6093 2022-12-31  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001816
# 6094 2022-12-31  A - SUSPECTED SERIOUS INJURY 1970-01-01 00:00:00.000001816
#
#      Day of Week     Latitude     Longitude  ... Weather Condition  \
# 0       SATURDAY  30.08917859  -95.45875665  ...        2 - CLOUDY
# 1       SATURDAY  26.20601218  -98.17643094  ...         1 - CLEAR
# 2       SATURDAY  26.20601218  -98.17643094  ...         1 - CLEAR
# 3       SATURDAY  26.20601218  -98.17643094  ...         1 - CLEAR
# 4       SATURDAY  32.77855464  -97.06134716  ...         1 - CLEAR
# ...          ...          ...           ...  ...               ...
# 6090    SATURDAY      No Data       No Data  ...         1 - CLEAR
# 6091    SATURDAY  32.83701347  -96.91476639  ...         1 - CLEAR
# 6092    SATURDAY  32.83701347  -96.91476639  ...         1 - CLEAR
# 6093    SATURDAY   29.7781673  -95.37264397  ...        2 - CLOUDY
# 6094    SATURDAY   29.7781673  -95.37264397  ...        2 - CLOUDY
#
#                                CMV Sequence of Events 1  \
# 0                 18 - COLLISION INVOLVING FIXED OBJECT
# 1                                               No Data
# 2                                               No Data
# 3     13 - COLLISION INVOLVING MOTOR VEHICLE IN TRAN...
# 4                                               No Data
# ...                                                 ...
# 6090                                            No Data
# 6091                12 - COLLISION INVOLVING PEDESTRIAN
# 6092                                            No Data
# 6093                        11 - NON-COLLISION: UNKNOWN
# 6094                                            No Data
#
#      CMV Sequence of Events 2 CMV Sequence of Events 3  \
# 0                     No Data                  No Data
# 1                     No Data                  No Data
# 2                     No Data                  No Data
# 3                     No Data                  No Data
# 4                     No Data                  No Data
# ...                       ...                      ...
# 6090                  No Data                  No Data
# 6091                  No Data                  No Data
# 6092                  No Data                  No Data
# 6093                  No Data                  No Data
# 6094                  No Data                  No Data
#
#      CMV Sequence of Events 4  \
# 0                     No Data
# 1                     No Data
# 2                     No Data
# 3                     No Data
# 4                     No Data
# ...                       ...
# 6090                  No Data
# 6091                  No Data
# 6092                  No Data
# 6093                  No Data
# 6094                  No Data
#
#                                   Contributing Factor 1 Person Age  \
# 0                       47 - ILL (EXPLAIN IN NARRATIVE)         34
# 1                          22 - FAILED TO CONTROL SPEED         32
# 2                                               No Data         57
# 3                          22 - FAILED TO CONTROL SPEED         42
# 4                          22 - FAILED TO CONTROL SPEED         20
# ...                                                 ...        ...
# 6090                  98 - OTHER (EXPLAIN IN NARRATIVE)         29
# 6091  59 - PEDESTRIAN FAILED TO YIELD RIGHT OF WAY T...         67
# 6092  59 - PEDESTRIAN FAILED TO YIELD RIGHT OF WAY T...         43
# 6093                  98 - OTHER (EXPLAIN IN NARRATIVE)         43
# 6094                                            No Data         38
#
#      Person Gender        Person Injury Severity  \
# 0         1 - MALE  A - SUSPECTED SERIOUS INJURY
# 1         1 - MALE           C - POSSIBLE INJURY
# 2         1 - MALE  A - SUSPECTED SERIOUS INJURY
# 3         1 - MALE    B - SUSPECTED MINOR INJURY
# 4       2 - FEMALE  A - SUSPECTED SERIOUS INJURY
# ...            ...                           ...
# 6090    2 - FEMALE  A - SUSPECTED SERIOUS INJURY
# 6091    2 - FEMALE               N - NOT INJURED
# 6092    2 - FEMALE              K - FATAL INJURY
# 6093      1 - MALE  A - SUSPECTED SERIOUS INJURY
# 6094      1 - MALE               N - NOT INJURED
#
#                                 Person Type
# 0                                1 - DRIVER
# 1                                1 - DRIVER
# 2     5 - DRIVER OF MOTORCYCLE TYPE VEHICLE
# 3                                1 - DRIVER
# 4                                1 - DRIVER
# ...                                     ...
# 6090                         4 - PEDESTRIAN
# 6091                             1 - DRIVER
# 6092                         4 - PEDESTRIAN
# 6093                             1 - DRIVER
# 6094                             1 - DRIVER
#
# [6095 rows x 23 columns]

# %%
crash_data['Latitude'] = pd.to_numeric(crash_data['Latitude'], errors='coerce')
crash_data['Longitude'] = pd.to_numeric(crash_data['Longitude'], errors='coerce')
crash_data['Person Age'] = pd.to_numeric(crash_data['Person Age'], errors='coerce')
crash_data['Person Age'] = pd.to_numeric(crash_data['Person Age'], errors='coerce')
crash_data['School Bus Flag'] = crash_data['School Bus Flag'].map({'Yes': True, 'No': False})
crash_data['Commercial Motor Vehicle Flag'] = crash_data['Commercial Motor Vehicle Flag'].map({'Yes': True, 'No': False})

# %%
crash_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6095 entries, 0 to 6094
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crash ID                       6095 non-null   int64
#  1   City                           6095 non-null   object
#  2   Commercial Motor Vehicle Flag  6095 non-null   bool
#  3   County                         6095 non-null   object
#  4   Crash Date                     6095 non-null   datetime64[ns]
#  5   Crash Severity                 6095 non-null   object
#  6   Crash Time                     6095 non-null   datetime64[ns]
#  7   Day of Week                    6095 non-null   object
#  8   Latitude                       5885 non-null   float64
#  9   Longitude                      5885 non-null   float64
#  10  School Bus Flag                6095 non-null   bool
#  11  Speed Limit                    6095 non-null   int64
#  12  Surface Condition              6095 non-null   object
#  13  Weather Condition              6095 non-null   object
#  14  CMV Sequence of Events 1       6095 non-null   object
#  15  CMV Sequence of Events 2       6095 non-null   object
#  16  CMV Sequence of Events 3       6095 non-null   object
#  17  CMV Sequence of Events 4       6095 non-null   object
#  18  Contributing Factor 1          6095 non-null   object
#  19  Person Age                     6022 non-null   float64
#  20  Person Gender                  6095 non-null   object
#  21  Person Injury Severity         6095 non-null   object
#  22  Person Type                    6095 non-null   object
# dtypes: bool(2), datetime64[ns](2), float64(3), int64(2), object(14)
# memory usage: 1012.0+ KB

# %%
crash_data["Person Age"].fillna("No Age", inplace = True)

# %%
(crash_data.isna().sum() + (crash_data == 'No Data').sum())
# Out:
# Crash ID                            0
# City                                0
# Commercial Motor Vehicle Flag       0
# County                              0
# Crash Date                          0
# Crash Severity                      0
# Crash Time                          0
# Day of Week                         0
# Latitude                          210
# Longitude                         210
# School Bus Flag                     0
# Speed Limit                         0
# Surface Condition                   0
# Weather Condition                   0
# CMV Sequence of Events 1         3031
# CMV Sequence of Events 2         5446
# CMV Sequence of Events 3         5833
# CMV Sequence of Events 4         6005
# Contributing Factor 1            2995
# Person Age                          0
# Person Gender                       0
# Person Injury Severity              0
# Person Type                         0
# dtype: int64

# %%
crash_data.to_csv('cleaned_crash_data.csv')
